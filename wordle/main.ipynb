# %% [markdown]
# # Game of WORDLE

# %% [markdown]
# Wordle is a popular word guessing game. Here are the rules of the game:
#
# The game begins with a randomly selected five-letter word.
# The player must guess the word within ten attempts.
#
# After each guess, the player will receive feedback in the form of a list of integers of length 5, containing either 0,1, or 2 (eg [0,0,1,2,1] or [1,1,2,0,1])
#
# If the ith integer is:
# *  0, then the ith letter of the guess is not present in the word
# * 1, then the ith letter of the guess is correctly positioned
# * 2, then the ith letter of the guess is present in the word but is misplaced.
#
# The player can use this feedback to refine their guesses and work towards solving the word.
# The game ends when the player correctly guesses the word or uses up all ten attempts.
#
#
# **You have been provided with most of the code to run the wordle game, to take in your guesses and to provide feedback. Your task is to code the ```generate_guess()``` function which takes as input a feedback which is a list of integers of length 5 containing either 0, 1 or 2 as explained earlier and returns the best possible guess of a 5 letter word.**
#
# The list of words to choose from is stored in the variable ```self.words```, and the correct word is guaranteed to belong to this list.
#
# The game runs your algorithm for 10 different words and prints out your guesses and whether you got the correct answer. Note that, an average human takes just above 4 guesses to solve a wordle. With 10 allowed guesses your algorithm has infact been given a lot of headroom. Try to do better than 10 and optimize as much as you can.

# %%
# from google.colab import drive
# import sys
# drive.mount('/content/drive/', force_remount = True)
# sys.path.append('/content/drive/MyDrive/wordle')
from utils import *

# %%
class Solver(Wordle):
    def __init__(self):
        super().__init__()

    def generate_guess(self, feedback=None):
        gspace=self.words
        guess = "hello"
        if feedback!=None:
            for i in range(5):
                list_conditions=[[],[],[]]
                if feedback[i]==0:

      

        return guess

# %%
game = Game(Solver, N=10)
game.run()
# Out:
# Simulating for  10  words.
#
# WORD #[ 1 / 10 ]
# 	Guess # 1 	: hello 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 2 	: hello 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 3 	: hello 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 4 	: hello 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 5 	: hello 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 6 	: hello 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 7 	: hello 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 8 	: hello 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 9 	: hello 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 10 	: hello 	Feedback:  [0, 1, 0, 0, 2]
# 	Failed to find correct word within 10 guesses. 	 Correct word:  pekoe
#
#
# WORD #[ 2 / 10 ]
# 	Guess # 1 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 2 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 3 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 4 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 5 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 6 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 7 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 8 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 9 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 10 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Failed to find correct word within 10 guesses. 	 Correct word:  trots
#
#
# WORD #[ 3 / 10 ]
# 	Guess # 1 	: hello 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 2 	: hello 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 3 	: hello 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 4 	: hello 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 5 	: hello 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 6 	: hello 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 7 	: hello 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 8 	: hello 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 9 	: hello 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 10 	: hello 	Feedback:  [0, 2, 0, 0, 0]
# 	Failed to find correct word within 10 guesses. 	 Correct word:  baste
#
#
# WORD #[ 4 / 10 ]
# 	Guess # 1 	: hello 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 2 	: hello 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 3 	: hello 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 4 	: hello 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 5 	: hello 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 6 	: hello 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 7 	: hello 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 8 	: hello 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 9 	: hello 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 10 	: hello 	Feedback:  [0, 2, 0, 0, 1]
# 	Failed to find correct word within 10 guesses. 	 Correct word:  cameo
#
#
# WORD #[ 5 / 10 ]
# 	Guess # 1 	: hello 	Feedback:  [2, 0, 0, 0, 2]
# 	Guess # 2 	: hello 	Feedback:  [2, 0, 0, 0, 2]
# 	Guess # 3 	: hello 	Feedback:  [2, 0, 0, 0, 2]
# 	Guess # 4 	: hello 	Feedback:  [2, 0, 0, 0, 2]
# 	Guess # 5 	: hello 	Feedback:  [2, 0, 0, 0, 2]
# 	Guess # 6 	: hello 	Feedback:  [2, 0, 0, 0, 2]
# 	Guess # 7 	: hello 	Feedback:  [2, 0, 0, 0, 2]
# 	Guess # 8 	: hello 	Feedback:  [2, 0, 0, 0, 2]
# 	Guess # 9 	: hello 	Feedback:  [2, 0, 0, 0, 2]
# 	Guess # 10 	: hello 	Feedback:  [2, 0, 0, 0, 2]
# 	Failed to find correct word within 10 guesses. 	 Correct word:  chops
#
#
# WORD #[ 6 / 10 ]
# 	Guess # 1 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 2 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 3 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 4 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 5 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 6 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 7 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 8 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 9 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 10 	: hello 	Feedback:  [0, 0, 0, 0, 2]
# 	Failed to find correct word within 10 guesses. 	 Correct word:  moons
#
#
# WORD #[ 7 / 10 ]
# 	Guess # 1 	: hello 	Feedback:  [2, 2, 0, 0, 0]
# 	Guess # 2 	: hello 	Feedback:  [2, 2, 0, 0, 0]
# 	Guess # 3 	: hello 	Feedback:  [2, 2, 0, 0, 0]
# 	Guess # 4 	: hello 	Feedback:  [2, 2, 0, 0, 0]
# 	Guess # 5 	: hello 	Feedback:  [2, 2, 0, 0, 0]
# 	Guess # 6 	: hello 	Feedback:  [2, 2, 0, 0, 0]
# 	Guess # 7 	: hello 	Feedback:  [2, 2, 0, 0, 0]
# 	Guess # 8 	: hello 	Feedback:  [2, 2, 0, 0, 0]
# 	Guess # 9 	: hello 	Feedback:  [2, 2, 0, 0, 0]
# 	Guess # 10 	: hello 	Feedback:  [2, 2, 0, 0, 0]
# 	Failed to find correct word within 10 guesses. 	 Correct word:  whine
#
#
# WORD #[ 8 / 10 ]
# 	Guess # 1 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 2 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 3 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 4 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 5 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 6 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 7 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 8 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 9 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 10 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Failed to find correct word within 10 guesses. 	 Correct word:  unfit
#
#
# WORD #[ 9 / 10 ]
# 	Guess # 1 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 2 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 3 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 4 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 5 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 6 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 7 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 8 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 9 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 10 	: hello 	Feedback:  [0, 0, 0, 0, 0]
# 	Failed to find correct word within 10 guesses. 	 Correct word:  spray
#
#
# WORD #[ 10 / 10 ]
# 	Guess # 1 	: hello 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 2 	: hello 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 3 	: hello 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 4 	: hello 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 5 	: hello 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 6 	: hello 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 7 	: hello 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 8 	: hello 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 9 	: hello 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 10 	: hello 	Feedback:  [0, 1, 0, 0, 0]
# 	Failed to find correct word within 10 guesses. 	 Correct word:  genus

# %% [markdown]
# $$
# E[I]=\sum p(x)\cdot (-\log_2(p(x))
# $$
